# %%
'''
NOTES:
Symptom Areas: Respiratory, Reproductive
Supervised Model: 
- Input: city, state, mold 
- Output: symptoms from respective category

TO DO:
- Separate files
    - File separating/creating new data frames based on category
    - Files modeling both data frames
    - Model results 
'''

# %%
import csv
import os
import pandas as pd

# %%
filename = os.path.join(os.getcwd(), 'Prepared_Data.csv')
df = pd.read_csv(filename, header = 0)

df.head()
# Out:
#              City    State  Aspergillus flavus/oryzae  Aspergillus fumigatus  \
# 0  Mountain Brook  Alabama                  -0.103755              -0.074702
# 1         Wasilla   Alaska                  -0.103755              -0.074702
# 2        Soldotna   Alaska                  -0.103755              -0.073301
# 3        Soldotna   Alaska                  -0.103755              -0.074702
# 4       Anchorage   Alaska                   0.380883              -0.072366
#
#    Aspergillus niger  Aspergillus ochraceus  Aspergillus penicillioides  \
# 0          -0.322177              -0.056391                   -0.068051
# 1          -0.324278              -0.056391                   -0.067824
# 2          -0.333732               0.048455                   -0.068051
# 3          -0.336884              -0.056391                   -0.068051
# 4          -0.303268              -0.056391                   -0.068051
#
# ...

# %%
# Renaming "Respiratory" column:
df = df.rename(columns={'Resipiratory':'Respiratory'})
df['Respiratory']
# Out:
# 0                                            No symptoms
# 1      Shortness of breath, Chronic dry cough, Chroni...
# 2            Shortness of breath, Heaviness in the chest
# 3                                            No symptoms
# 4                                            No symptoms
#                              ...
# 548                                          No symptoms
# 549                                          No symptoms
# 550                                      Asthma/Wheezing
# 551                                          No symptoms
# 552                                  Shortness of breath
# Name: Respiratory, Length: 553, dtype: object

# %%
# Dropping "City", "State" columns:
df = df.drop(columns=['City','State'], axis = 1)
df.head()
# Out:
#    Aspergillus flavus/oryzae  Aspergillus fumigatus  Aspergillus niger  \
# 0                  -0.103755              -0.074702          -0.322177
# 1                  -0.103755              -0.074702          -0.324278
# 2                  -0.103755              -0.073301          -0.333732
# 3                  -0.103755              -0.074702          -0.336884
# 4                   0.380883              -0.072366          -0.303268
#
#    Aspergillus ochraceus  Aspergillus penicillioides  Aspergillus restrictus  \
# 0              -0.056391                   -0.068051               -0.148075
# 1              -0.056391                   -0.067824               -0.203413
# 2               0.048455                   -0.068051               -0.173229
# 3              -0.056391                   -0.068051               -0.203413
# 4              -0.056391                   -0.068051               -0.173229
#
#    Aspergillus sclerotiorum  Aspergillus sydowii  Aspergillus unguis  \
# ...

# %%
# Creating new df for each category: 
df_resp = df.copy()
df_repr = df.copy()

# %%
# Removing all other categories from df_resp:
drop_resp = ['Diagnoses','Eyes, Ears, Nose, & Throat','Urinary', 'Digestive','Circulatory', 'Skin', 'Brain', 'Nervous', 'Immune', 'Reproductive'] 
df_resp = df_resp.drop(columns=drop_resp)
df_resp.head()
# Out:
#    Aspergillus flavus/oryzae  Aspergillus fumigatus  Aspergillus niger  \
# 0                  -0.103755              -0.074702          -0.322177
# 1                  -0.103755              -0.074702          -0.324278
# 2                  -0.103755              -0.073301          -0.333732
# 3                  -0.103755              -0.074702          -0.336884
# 4                   0.380883              -0.072366          -0.303268
#
#    Aspergillus ochraceus  Aspergillus penicillioides  Aspergillus restrictus  \
# 0              -0.056391                   -0.068051               -0.148075
# 1              -0.056391                   -0.067824               -0.203413
# 2               0.048455                   -0.068051               -0.173229
# 3              -0.056391                   -0.068051               -0.203413
# 4              -0.056391                   -0.068051               -0.173229
#
#    Aspergillus sclerotiorum  Aspergillus sydowii  Aspergillus unguis  \
# ...

# %%
# Removing all other categories from df_repr:
drop_repr = ['Diagnoses','Eyes, Ears, Nose, & Throat','Urinary', 'Digestive','Circulatory', 'Skin', 'Brain', 'Nervous', 'Immune', 'Respiratory'] 
df_repr = df_repr.drop(columns=drop_repr)
df_repr.head()
# Out:
#    Aspergillus flavus/oryzae  Aspergillus fumigatus  Aspergillus niger  \
# 0                  -0.103755              -0.074702          -0.322177
# 1                  -0.103755              -0.074702          -0.324278
# 2                  -0.103755              -0.073301          -0.333732
# 3                  -0.103755              -0.074702          -0.336884
# 4                   0.380883              -0.072366          -0.303268
#
#    Aspergillus ochraceus  Aspergillus penicillioides  Aspergillus restrictus  \
# 0              -0.056391                   -0.068051               -0.148075
# 1              -0.056391                   -0.067824               -0.203413
# 2               0.048455                   -0.068051               -0.173229
# 3              -0.056391                   -0.068051               -0.203413
# 4              -0.056391                   -0.068051               -0.173229
#
#    Aspergillus sclerotiorum  Aspergillus sydowii  Aspergillus unguis  \
# ...

# %%
# Creating new CSV files:
df_resp.to_csv('Respiratory_Symptoms.csv', index = False)
df_repr.to_csv('Reproductive_Symptoms.csv', index = False)
